# %%
#Visualizacao crua dos Dados


import pandas as pd
import json

caminho_arquivo = "input/Projetos de Desenvolvimento Tecnologico.json"

# Abri o JSON
with open(caminho_arquivo, encoding="utf-8") as f:
    dados = json.load(f)

# Converter para DataFrame
df = pd.DataFrame(dados)

# Visualizar os primeiros dados
df.head()
# Out:
#   Projeto_ID    Segmento     Status Sub-issues progress  \
# 0   PROJ-001  Tecnologia  Concluído              97,00%
# 1   PROJ-002       Saúde  Concluído              71,00%
# 2   PROJ-003    Educação  Concluído              15,00%
# 3   PROJ-004   Segurança  Concluído              77,00%
# 4   PROJ-005    Educação  Concluído              64,00%
#
#   Interveniência com o IA-UPE Convênio ou acordo           Edital  \
# 0                         Não           Convênio  Edital 243/2024
# 1                         Não           Convênio  Edital 998/2020
# 2                         Não             Acordo  Edital 774/2020
# 3                         Sim             Acordo  Edital 978/2022
# 4                         Não           Convênio  Edital 905/2020
#
#   Acordo/convênio n.º  Aditivo n.º Tipo de aditivo  ... Valor contrapartida  \
# 0           5335/2021            4          Outros  ...           15.927,57
# ...

# %%
# Exportar os dados tratados
df.to_csv('output/dados_tratados.csv', index=False, encoding='utf-8-sig')
